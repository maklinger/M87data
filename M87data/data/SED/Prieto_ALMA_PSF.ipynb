# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots()

ax.loglog([0.937, 6.35], [0.33, 2.7])
ax.loglog([0.937, 6.35], [0.3, 2])
ax.loglog([0.937, 6.35], [0.28, 1.5])

for i in [0.937, 1.08, 2.21, 2.52, 2.86, 3.5, 6.35]:
    ax.axvline(i)
# values used
for i in [0.3, 0.34, 0.7, 0.8, 0.9, 1.1, 2]:
    ax.axhline(i, c="grey")
